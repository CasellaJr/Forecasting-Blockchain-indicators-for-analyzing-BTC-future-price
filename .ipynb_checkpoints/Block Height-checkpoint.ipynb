# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

#Statistics
# Statistics
import pmdarima as pm
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing
from statsmodels.tsa.seasonal import seasonal_decompose, STL
from statsmodels.tsa.stattools import adfuller
from statsmodels.stats.stattools import durbin_watson
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from scipy.special import inv_boxcox
from scipy.stats import boxcox
from scipy.interpolate import interp1d

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from dateutil.parser import parse 
import pickle

# %% [markdown]
# # READ CSV AND DESCRIPTION OF SERIES

# %%
#BLOCK HEIGHT
block_height = pd.read_csv("data/bitcoin-block-height.csv")

block_height["Block Height/t"] = block_height["Block Height/t"].str.rstrip("T00:00:00.000Z")
block_height["Block Height/t"] = pd.to_datetime(block_height["Block Height/t"])
block_height = block_height.sort_values(by='Block Height/t')
block_height = block_height.rename(columns={'Block Height/t': 'Timestamp', 'Block Height/v': 'Value'})

#Description
print(block_height.head())
print("\nShape is:", block_height.shape)
print("\nSummary of the dataset:")
block_height.describe()
print("\nAre there null values?")
block_height.isna().sum()
# Out:
#     Timestamp  Value
# 1  2009-01-01     75
# 11 2009-01-02   1193
# 21 2009-01-03   2405
# 0  2009-01-09     14
# 2  2009-01-11    168
#
# Shape is: (4982, 2)
#
# Summary of the dataset:
#
# Are there null values?
# Timestamp    0
# Value        0
# dtype: int64

# %% [markdown]
# # VISUALIZATION

# %%
plt.figure(figsize=(16,5))
plt.plot(block_height["Timestamp"], block_height["Value"])
plt.gca().set(xlabel="Year", ylabel="Value")
#scommentare riga giù per visualizzare in scala log
#plt.yscale('log') 
plt.show()

#FIX THIS VIS LIKE GLASSNODE

#CAPIRE PERCHE' SI VEDONO QUEI "PICCHI" (credo si vedano perchè il range y è troppo alto)

# %%
plt.figure(figsize=(16,5))
sns.histplot(block_height["Value"], kde = False, bins = 60)
plt.title('Distribution of the Block Height', fontsize=16)
plt.show()

# %%
ann = []
for el in [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]:
    ann.append(block_height['Timestamp'][block_height['Timestamp'].dt.year == el].shape[0])
ann
# Out:
# [357, 365, 365, 366, 365, 365, 365, 366, 365, 365, 365, 366, 365]

# %%
# abbiamo i dati di ogni gionro di ogni anno... ne bastano meno
# data anche la serie temporale molto standard
block_h = block_height.iloc[::3,:]

# %%
res1 = STL(block_h["Value"], period = 121, robust = True).fit()
res2 = STL(block_h["Value"], period = 121).fit()

# %%
fig, axs = plt.subplots(ncols=3, figsize=(18,6))
axs[0].plot(res1.resid, label="robust")
axs[0].plot(res2.resid, label="no robust")
axs[0].legend()
axs[1].plot(res1.seasonal)
axs[1].plot(res2.seasonal)
axs[2].plot(res1.trend)
axs[2].plot(res2.trend)

# %% [markdown]
# The not robust one is better because of the more constant residuals. still, we can see from the right plot that if we fit the trend it will be a straight line (the blue one) so we have to use the robust one.
